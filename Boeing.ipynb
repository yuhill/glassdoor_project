# %%
import requests
import bs4
import pandas as pd
import numpy as np
from decimal import *

# %%
s = requests.session()
headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:54.0) Gecko/20100101 Firefox/54.0'}
s.get("https://www.glassdoor.com", headers=headers)
parsed_boeing = bs4.BeautifulSoup(s.get("https://www.glassdoor.com/Salary/Boeing-Salaries-E102.htm", headers=headers).text, 'html.parser')

# %%
parsed_boeing
# Out:
# <!DOCTYPE html>
#
# <html class="flex" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/">
# <script>
# 	window.gdGlobals = window.gdGlobals ||
# 		[{
# 			'analyticsId':                      "UA-2595786-1",
#
#
# 			'analyticsUrl':                     "/employerInfo/Salaries/employer-summary",
#
# 			'deferredScriptType':               "text/x-deferred-js",
# 			'accessDeniedRedirectUrl':          '',
# 			'locale': 							'en-US',
# 			'env': 'prod',
#
#
# 			'device':       {
#
#
# 								'handheld':     false,
#
#
# 								'tablet':       	false,
# 								'deviceTypeId': 	1,
# 								'platformTypeId': 	3,
# 								'viewTypeId': 		4
# 							},
# 			'page':         {
#
# 								'domain':       "www.glassdoor.com",
# 								'domainId':		1,
#
#
# 								'domainSuffix': "",
#
#
# 								'group':        "EI-Salaries",
#
#
# 								'guid':         '0000015dbf7ae2c99708ea074d7f771e',
#
#
# 								'flex':         true,
#
#
# ...

# %%
salaries_html = parsed_boeing.find_all('div', class_="salaryChartModule")[0]

# %%
list_of_salary_divs = salaries_html.find_all('div', class_="meanPay alignRt")

# %%
list_of_salary_divs
# Out:
# [<div class="meanPay alignRt"><strong>$97,380</strong> per year</div>,
#  <div class="meanPay alignRt"><strong>$99,128</strong> per year</div>,
#  <div class="meanPay alignRt"><strong>$81,599</strong> per year</div>,
#  <div class="meanPay alignRt"><strong>$88,646</strong> per year</div>,
#  <div class="meanPay alignRt"><strong>$23.92</strong> hourly</div>,
#  <div class="meanPay alignRt"><strong>$89,510</strong> per year</div>,
#  <div class="meanPay alignRt"><strong>$94,051</strong> per year</div>,
#  <div class="meanPay alignRt"><strong>$68,103</strong> per year</div>,
#  <div class="meanPay alignRt"><strong>$99,270</strong> per year</div>,
#  <div class="meanPay alignRt"><strong>$60,032</strong> per year</div>,
#  <div class="meanPay alignRt"><strong>$73,215</strong> per year</div>,
#  <div class="meanPay alignRt"><strong>$82,200</strong> per year</div>,
#  <div class="meanPay alignRt"><strong>$76,206</strong> per year</div>,
# ...

# %%
salaries_html2=list_of_salary_divs

# %%
print(salaries_html2.get_text())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-8f906d4fb9bf> in <module>()
# ----> 1 print(salaries_html2.get_text())
#
# c:\users\jhill\appdata\local\continuum\miniconda3\envs\pumpkins\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
result_list = []
for salary_div in list_of_salary_divs:
    salary_text = salary_div.get_text()
    result_list.append(salary_text)
result_list
# Out:
# ['$97,380 per year',
#  '$99,128 per year',
#  '$81,599 per year',
#  '$88,646 per year',
#  '$23.92 hourly',
#  '$89,510 per year',
#  '$94,051 per year',
#  '$68,103 per year',
#  '$99,270 per year',
#  '$60,032 per year',
#  '$73,215 per year',
#  '$82,200 per year',
#  '$76,206 per year',
#  '$68,967 per year',
#  '$62,164 per year']

# %%
type(list_of_salary_divs)
# Out:
# bs4.element.ResultSet

# %%
result_list = []
for salary_div in list_of_salary_divs:
    result_list.append(salary_div.get_text())
result_list
# Out:
# ['$97,380 per year',
#  '$99,128 per year',
#  '$81,599 per year',
#  '$88,646 per year',
#  '$23.92 hourly',
#  '$89,510 per year',
#  '$94,051 per year',
#  '$68,103 per year',
#  '$99,270 per year',
#  '$60,032 per year',
#  '$73,215 per year',
#  '$82,200 per year',
#  '$76,206 per year',
#  '$68,967 per year',
#  '$62,164 per year']

# %%
list_of_title_divs = parsed_boeing.find_all('a', class_="noMargVert jobTitle")

# %%
result_list2 = []
for title_div in list_of_title_divs:
    title_text = title_div.get_text()
    result_list2.append(title_text)
result_list2
# Out:
# ['Systems Engineer ',
#  'Software Engineer III ',
#  'Software Engineer II ',
#  'Software Engineer ',
#  'Intern - Hourly',
#  'Engineer ',
#  'Project Manager ',
#  'Software Engineer I ',
#  'Systems Engineer III ',
#  'Procurement Agent II ',
#  'Procurement Agent III ',
#  'Systems Engineer II ',
#  'Manufacturing Engineer ',
#  'Business Analyst ',
#  'Financial Analyst ']

# %%
ziped=dict(zip(result_list2,result_list))

# %%
ziped=list(zip(result_list2,result_list))

# %%
ziped
# Out:
# [('Systems Engineer ', '$97,380 per year'),
#  ('Software Engineer III ', '$99,128 per year'),
#  ('Software Engineer II ', '$81,599 per year'),
#  ('Software Engineer ', '$88,646 per year'),
#  ('Intern - Hourly', '$23.92 hourly'),
#  ('Engineer ', '$89,510 per year'),
#  ('Project Manager ', '$94,051 per year'),
#  ('Software Engineer I ', '$68,103 per year'),
#  ('Systems Engineer III ', '$99,270 per year'),
#  ('Procurement Agent II ', '$60,032 per year'),
#  ('Procurement Agent III ', '$73,215 per year'),
#  ('Systems Engineer II ', '$82,200 per year'),
#  ('Manufacturing Engineer ', '$76,206 per year'),
#  ('Business Analyst ', '$68,967 per year'),
#  ('Financial Analyst ', '$62,164 per year')]

# %%
ziped['Manufacturing Engineer ']
# Out:
# '$76,206 per year'

# %%
result_list.append(result_list2)

# %%
result_list
# Out:
# ['$97,380 per year',
#  '$99,128 per year',
#  '$81,599 per year',
#  '$88,646 per year',
#  '$23.92 hourly',
#  '$89,510 per year',
#  '$94,051 per year',
#  '$68,103 per year',
#  '$99,270 per year',
#  '$60,032 per year',
#  '$73,215 per year',
#  '$82,200 per year',
#  '$76,206 per year',
#  '$68,967 per year',
#  '$62,164 per year',
#  ['Systems Engineer ',
#   'Software Engineer III ',
#   'Software Engineer II ',
#   'Software Engineer ',
#   'Intern - Hourly',
#   'Engineer ',
#   'Project Manager ',
#   'Software Engineer I ',
#   'Systems Engineer III ',
#   'Procurement Agent II ',
#   'Procurement Agent III ',
#   'Systems Engineer II ',
#   'Manufacturing Engineer ',
#   'Business Analyst ',
#   'Financial Analyst ']]

# %%
length(result_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-f42e995c5e93> in <module>()
# ----> 1 length(result_list)
#
# NameError: name 'length' is not defined

# %%
print(type(result_list))
# Out:
# <class 'list'>

# %%
percentile_list = pd.DataFrame(np.column_stack([result_list, result_list2]), 
                               columns=['Title', 'Salary'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-a088bff3029c> in <module>()
# ----> 1 percentile_list = pd.DataFrame(np.column_stack([result_list, result_list2]),
#       2                                columns=['Title', 'Salary'])
#
# c:\users\jhill\appdata\local\continuum\miniconda3\envs\pumpkins\lib\site-packages\numpy\lib\shape_base.py in column_stack(tup)
#     347     arrays = []
#     348     for v in tup:
# --> 349         arr = array(v, copy=False, subok=True)
#     350         if arr.ndim < 2:
#     351             arr = array(arr, copy=False, subok=True, ndmin=2).T
#
# ValueError: setting an array element with a sequence

# %%
data=np.matrix([result_list, result_list2])

# %%
print(data)
# Out:
# [[ list(['$97,380 per year', '$99,128 per year', '$81,599 per year', '$88,646 per year', '$23.92 hourly', '$89,510 per year', '$94,051 per year', '$68,103 per year', '$99,270 per year', '$60,032 per year', '$73,215 per year', '$82,200 per year', '$76,206 per year', '$68,967 per year', '$62,164 per year', ['Systems Engineer ', 'Software Engineer III ', 'Software Engineer II ', 'Software Engineer ', 'Intern - Hourly', 'Engineer ', 'Project Manager ', 'Software Engineer I ', 'Systems Engineer III ', 'Procurement Agent II ', 'Procurement Agent III ', 'Systems Engineer II ', 'Manufacturing Engineer ', 'Business Analyst ', 'Financial Analyst ']])
# ...

# %%
data=pd.DataFrame(
    {'Title' : [result_list] ,
     'Salary' :[result_list2]
    })

# %%
results = [result_list] + [result_list2]

# %%
results
# Out:
# [['$97,380 per year',
#   '$99,128 per year',
#   '$81,599 per year',
#   '$88,646 per year',
#   '$23.92 hourly',
#   '$89,510 per year',
#   '$94,051 per year',
#   '$68,103 per year',
#   '$99,270 per year',
#   '$60,032 per year',
#   '$73,215 per year',
#   '$82,200 per year',
#   '$76,206 per year',
#   '$68,967 per year',
#   '$62,164 per year',
#   ['Systems Engineer ',
#    'Software Engineer III ',
#    'Software Engineer II ',
#    'Software Engineer ',
#    'Intern - Hourly',
#    'Engineer ',
#    'Project Manager ',
#    'Software Engineer I ',
#    'Systems Engineer III ',
#    'Procurement Agent II ',
#    'Procurement Agent III ',
#    'Systems Engineer II ',
#    'Manufacturing Engineer ',
#    'Business Analyst ',
#    'Financial Analyst ']],
#  ['Systems Engineer ',
#   'Software Engineer III ',
#   'Software Engineer II ',
#   'Software Engineer ',
#   'Intern - Hourly',
#   'Engineer ',
#   'Project Manager ',
#   'Software Engineer I ',
# ...

# %%
results_list.
# Out:
#   File "<ipython-input-38-5294c7df0652>", line 1
#     results_list.
#                  ^
# SyntaxError: invalid syntax

# %%
salaries = result_list

# %%
salaries
# Out:
# ['$97,380 per year',
#  '$99,128 per year',
#  '$81,599 per year',
#  '$88,646 per year',
#  '$23.92 hourly',
#  '$89,510 per year',
#  '$94,051 per year',
#  '$68,103 per year',
#  '$99,270 per year',
#  '$60,032 per year',
#  '$73,215 per year',
#  '$82,200 per year',
#  '$76,206 per year',
#  '$68,967 per year',
#  '$62,164 per year']

# %%
def number_func(salary_line):
    salary=salary_line.split()[0][1:]
    salary=Decimal(salary.replace(",",""))
    return salary

# %%
number_func(salaries[0])
# Out:
# Decimal('97380')

# %%
all_salaries=list()
for salary_line in salaries:
    all_salaries.append(number_func(salary_line))
print(all_salaries)
# Out:
# [Decimal('97380'), Decimal('99128'), Decimal('81599'), Decimal('88646'), Decimal('23.92'), Decimal('89510'), Decimal('94051'), Decimal('68103'), Decimal('99270'), Decimal('60032'), Decimal('73215'), Decimal('82200'), Decimal('76206'), Decimal('68967'), Decimal('62164')]

# %%
all_salaries.sort()
print(all_salaries)
# Out:
# [Decimal('23.92'), Decimal('60032'), Decimal('62164'), Decimal('68103'), Decimal('68967'), Decimal('73215'), Decimal('76206'), Decimal('81599'), Decimal('82200'), Decimal('88646'), Decimal('89510'), Decimal('94051'), Decimal('97380'), Decimal('99128'), Decimal('99270')]

# %%
print(max(all_salaries))
# Out:
# 99270

# %%
print(min(all_salaries))
# Out:
# 23.92

# %%
all_salaries2 = [number_func(salary_line) for salary_line in salaries]

# %%
print(all_salaries2)
# Out:
# [Decimal('97380'), Decimal('99128'), Decimal('81599'), Decimal('88646'), Decimal('23.92'), Decimal('89510'), Decimal('94051'), Decimal('68103'), Decimal('99270'), Decimal('60032'), Decimal('73215'), Decimal('82200'), Decimal('76206'), Decimal('68967'), Decimal('62164')]
